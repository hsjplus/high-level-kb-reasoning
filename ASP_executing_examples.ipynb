# %%
# Copyright 2020 The authors of the paper (https://arxiv.org/abs/2011.12081) 
# The paper's title: "Tackling Domain-Specific Winograd Schemas with Knowledge-Based Reasoning and Machine Learning"

# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at

#        http://www.apache.org/licenses/LICENSE-2.0

#  Unless required by applicable law or agreed to in writing, software
#  distributed under the License is distributed on an "AS IS" BASIS,
#  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  See the License for the specific language governing permissions and
#  limitations under the License.

import main

# %%
ex1_pred = main.predict(experiment_type='ex1')
# Out:
# No duplicates between the train set and the test set
# The number of sentences in the train set:  40
# The number of sentences in the test set:  40
# The number of the derived background knowledge principles:  23
# Waiting for the predictions...
# 1a
# 2b
# 4b
# 5a
# 6a
# 9b
# 10a
# 12a
# 15a
# 16a
# 17a
# 18a
# 22b
# 23b
# 25a
# 26a
# 28b
# 29b
# 30b
# 31a
# 32b
# 33b
# 34b
# 35a
# 36b
# 37a
# 38a
# 39b
# 40a
# 42b
# 43b
# 44a
# 45a
# 46a
# 48a
# 49a
# 50b
# 51b
# 52a
# 53b
# ...

# %%
main.evaluate(experiment_type='ex1', pred_dict=ex1_pred)
# Out:
# ex1  accuracy:  0.725
# ex1  results are saved to: ./results/ex1_krr_result.csv
#    test_pid      test_label         test_pred  correct
# 0        1a         jeffrey         no_answer    False
# 1        2b          rachel            rachel     True
# 2        4b           sarah             sarah     True
# 3        5a        patricia          patricia     True
# 4        6a            eric              eric     True
# 5        9b           kayla             kayla     True
# 6       10a           megan             megan     True
# 7       12a           craig             craig     True
# 8       15a          joseph            joseph     True
# 9       16a          monica         no_answer    False
# 10      17a        lawrence         no_answer    False
# 11      18a          subway         no_answer    False
# 12      22b          dennis            dennis     True
# 13      23b  thank_you_note    thank_you_note     True
# 14      25a            kyle  multiple_answers    False
# ...

# %%
ex2_pred = main.predict(experiment_type='ex2')
# Out:
# No duplicates between the train set and the test set
# The number of sentences in the train set:  40
# The number of sentences in the test set:  40
# The number of the derived background knowledge principles:  19
# Waiting for the predictions...
# 1a
# 1b
# 5a
# 5b
# 6a
# 6b
# 9a
# 9b
# 15a
# 15b
# 17a
# 17b
# 26a
# 26b
# 28a
# 28b
# 29a
# 29b
# 30a
# 30b
# 31a
# 31b
# 34a
# 34b
# 35a
# 35b
# 36a
# 36b
# 40a
# 40b
# 42a
# 42b
# 43a
# 43b
# 45a
# 45b
# 46a
# 46b
# 50a
# 50b
# ...

# %%
main.evaluate(experiment_type='ex2', pred_dict=ex2_pred)
# Out:
# ex2  accuracy:  0.375
# ex2  results are saved to: ./results/ex2_krr_result.csv
#    test_pid test_label  test_pred  correct
# 0        1a    jeffrey  no_answer    False
# 1        1b   lawrence  no_answer    False
# 2        5a   patricia  no_answer    False
# 3        5b    lindsey  no_answer    False
# 4        6a       eric  no_answer    False
# 5        6b     robert       eric    False
# 6        9a      emily      emily     True
# 7        9b      kayla      kayla     True
# 8       15a     joseph     joseph     True
# 9       15b      kevin      kevin     True
# 10      17a   lawrence  no_answer    False
# 11      17b      craig      craig     True
# 12      26a      elena  no_answer    False
# 13      26b   samantha  no_answer    False
# 14      28a      laura  no_answer    False
# 15      28b      megan  no_answer    False
# 16      29a     nelson     nelson     True
# 17      29b     samuel     samuel     True
# 18      30a      maria  no_answer    False
# ...
